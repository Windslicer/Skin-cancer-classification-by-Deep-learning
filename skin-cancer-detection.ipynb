# %% [markdown]
# # Import needed libraries

# %%
# import system libs 
import os
import time
import shutil
import itertools

# import data handling tools 
import cv2
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt

# import Deep learning Libraries
import tensorflow as tf
from tensorflow import keras
import keras
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Activation, Dropout, BatchNormalization
from keras.models import Model, load_model, Sequential
from keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from keras.optimizers import Adam, Adamax
from keras import regularizers
from keras.metrics import categorical_crossentropy

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# modules loaded

# %% [markdown]
# ### Read data

# %%
#                   C:/Users/DARTHVADER/Desktop/Skin_Cancer_Detection/hmnist_28_28_RGB.csv
data_dir = 'C:/Users/DARTHVADER/Desktop/Skin_Cancer_Detection/hmnist_28_28_RGB.csv'
data = pd.read_csv(data_dir)
data.head()
# Out:
#    pixel0000  pixel0001  pixel0002  pixel0003  pixel0004  pixel0005  \
# 0        192        153        193        195        155        192
# 1         25         14         30         68         48         75
# 2        192        138        153        200        145        163
# 3         38         19         30         95         59         72
# 4        158        113        139        194        144        174
#
#    pixel0006  pixel0007  pixel0008  pixel0009  ...  pixel2343  pixel2344  \
# 0        197        154        185        202  ...        173        124
# 1        123         93        126        158  ...         60         39
# 2        201        142        160        206  ...        167        129
# 3        143        103        119        171  ...         44         26
# 4        215        162        191        225  ...        209        166
#
#    pixel2345  pixel2346  pixel2347  pixel2348  pixel2349  pixel2350  \
# ...

# %% [markdown]
# # **Data Preprocessing**

# %% [markdown]
# ### Split data and labels

# %%
Label = data["label"]
Data = data.drop(columns=["label"])

# %% [markdown]
# ### Handling imbalanced datasets

# %%
from imblearn.over_sampling import RandomOverSampler 

oversample = RandomOverSampler()
Data, Label  = oversample.fit_resample(Data, Label)
Data = np.array(Data).reshape(-1, 28, 28, 3)
print('Shape of Data :', Data.shape)
# Out:
# Shape of Data : (46935, 28, 28, 3)

# %%
Label = np.array(Label)
Label
# Out:
# array([2, 2, 2, ..., 6, 6, 6], dtype=int64)

# %% [markdown]
# ### Convert abbreviations to it's words

# %%
classes = {4: ('nv', ' melanocytic nevi'),
           6: ('mel', 'melanoma'),
           2 :('bkl', 'benign keratosis-like lesions'), 
           1: ('bcc' , ' basal cell carcinoma'),
           5: ('vasc', ' pyogenic granulomas and hemorrhage'),
           0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),
           3: ('df', 'dermatofibroma')}

# %% [markdown]
# ### Splitting train and test

# %%
from sklearn.model_selection import train_test_split# 75% TRAIN

X_train , X_test , y_train , y_test = train_test_split(Data , Label , test_size = 0.25 , random_state = 49)

# %%
print(f'X_train shape: {X_train.shape}\nX_test shape: {X_test.shape}')
print(f'y_train shape: {y_train.shape}\ny_test shape: {y_test.shape}')
# Out:
# X_train shape: (35201, 28, 28, 3)
# X_test shape: (11734, 28, 28, 3)
# y_train shape: (35201,)
# y_test shape: (11734,)

# %% [markdown]
# ### Convert labels to categorical types

# %%
from keras.utils.np_utils import to_categorical

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# ### Create Image Data Generation

# %%
datagen = ImageDataGenerator(rescale=(1./255)
                             ,rotation_range=10
                             ,zoom_range = 0.1
                             ,width_shift_range=0.1
                             ,height_shift_range=0.1)

testgen = ImageDataGenerator(rescale=(1./255))

# %% [markdown]
# ### Create ReduceLROnPlateau to learning rate reduction

# %%
# Feature Engineering Part for model
from keras.callbacks import ReduceLROnPlateau

learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy'
                                            , patience = 2
                                            , verbose=1
                                            ,factor=0.5
                                            , min_lr=0.00001)

# %% [markdown]
# # Model Structure

# %%
model = keras.models.Sequential()

# Create Model Structure
model.add(keras.layers.Input(shape=[28, 28, 3]))
model.add(keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal'))
model.add(keras.layers.MaxPooling2D())
model.add(keras.layers.BatchNormalization())

model.add(keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal'))
model.add(keras.layers.Conv2D(64, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal'))
model.add(keras.layers.MaxPooling2D())
model.add(keras.layers.BatchNormalization())

model.add(keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal'))
model.add(keras.layers.Conv2D(128, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal'))
model.add(keras.layers.MaxPooling2D())
model.add(keras.layers.BatchNormalization())

model.add(keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal'))
model.add(keras.layers.Conv2D(256, (3, 3), activation='relu', padding='same', kernel_initializer='he_normal'))
model.add(keras.layers.MaxPooling2D())

model.add(keras.layers.Flatten())

model.add(keras.layers.Dropout(rate=0.2))
model.add(keras.layers.Dense(units=256, activation='relu', kernel_initializer='he_normal'))
model.add(keras.layers.BatchNormalization())

model.add(keras.layers.Dense(units=128, activation='relu', kernel_initializer='he_normal'))
model.add(keras.layers.BatchNormalization())

model.add(keras.layers.Dense(units=64, activation='relu', kernel_initializer='he_normal'))
model.add(keras.layers.BatchNormalization())

model.add(keras.layers.Dense(units=32, activation='relu', kernel_initializer='he_normal', kernel_regularizer=keras.regularizers.L1L2()))
model.add(keras.layers.BatchNormalization())

model.add(keras.layers.Dense(units=7, activation='softmax', kernel_initializer='glorot_uniform', name='classifier'))

model.compile(Adamax(learning_rate= 0.001), loss= 'categorical_crossentropy', metrics= ['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 28, 28, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 32)       0
#  )
#
#  batch_normalization (BatchN  (None, 14, 14, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 64)        18496
#
#  conv2d_2 (Conv2D)           (None, 14, 14, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 64)         0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 7, 7, 64)         256
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 7, 7, 128)         73856
#
#  conv2d_4 (Conv2D)           (None, 7, 7, 128)         147584
#
#  max_pooling2d_2 (MaxPooling  (None, 3, 3, 128)        0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 3, 3, 128)        512
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 3, 3, 256)         295168
#
# ...

# %% [markdown]
# ### Training model

# %%
history = model.fit(X_train ,
                    y_train ,
                    epochs=25 ,
                    batch_size=128,
                    validation_data=(X_test , y_test) ,
                    callbacks=[learning_rate_reduction])
# Out:
# Epoch 1/25
# 276/276 [==============================] - 19s 34ms/step - loss: 1.2553 - accuracy: 0.5389 - val_loss: 0.9376 - val_accuracy: 0.6581 - lr: 0.0010
# Epoch 2/25
# 276/276 [==============================] - 7s 27ms/step - loss: 0.5678 - accuracy: 0.8026 - val_loss: 0.4599 - val_accuracy: 0.8315 - lr: 0.0010
# Epoch 3/25
# 276/276 [==============================] - 7s 27ms/step - loss: 0.3316 - accuracy: 0.8842 - val_loss: 0.2820 - val_accuracy: 0.9018 - lr: 0.0010
# Epoch 4/25
# 276/276 [==============================] - 7s 27ms/step - loss: 0.2386 - accuracy: 0.9175 - val_loss: 0.2011 - val_accuracy: 0.9296 - lr: 0.0010
# Epoch 5/25
# 276/276 [==============================] - 8s 27ms/step - loss: 0.1652 - accuracy: 0.9433 - val_loss: 0.1986 - val_accuracy: 0.9280 - lr: 0.0010
# Epoch 6/25
# 274/276 [============================>.] - ETA: 0s - loss: 0.1278 - accuracy: 0.9562
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# ...

# %% [markdown]
# ### Show training history

# %%
def plot_training(hist):
    tr_acc = hist.history['accuracy']
    tr_loss = hist.history['loss']
    val_acc = hist.history['val_accuracy']
    val_loss = hist.history['val_loss']
    index_loss = np.argmin(val_loss)
    val_lowest = val_loss[index_loss]
    index_acc = np.argmax(val_acc)
    acc_highest = val_acc[index_acc]

    plt.figure(figsize= (20, 8))
    plt.style.use('fivethirtyeight')
    Epochs = [i+1 for i in range(len(tr_acc))]
    loss_label = f'best epoch= {str(index_loss + 1)}'
    acc_label = f'best epoch= {str(index_acc + 1)}'
    
    plt.subplot(1, 2, 1)
    plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
    plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
    plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
    plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
    plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    
    plt.tight_layout
    plt.show()

# %%
plot_training(history)

# %% [markdown]
# # Model Evaluation

# %%
train_score = model.evaluate(X_train, y_train, verbose= 1)
test_score = model.evaluate(X_test, y_test, verbose= 1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# ...
# 367/367 [==============================] - 2s 7ms/step - loss: 0.0604 - accuracy: 0.9848
# Train Loss:  0.0003575956216081977
# Train Accuracy:  0.9999715685844421
# --------------------
# Test Loss:  0.06037161871790886
# Test Accuracy:  0.984830379486084

# %%
y_true = np.array(y_test)
y_pred = model.predict(X_test)

y_pred = np.argmax(y_pred , axis=1)
y_true = np.argmax(y_true , axis=1)
# Out:
# 367/367 [==============================] - 2s 5ms/step

# %% [markdown]
# ### Create classes labels

# %%
classes_labels = []
for key in classes.keys():
    classes_labels.append(key)

print(classes_labels)
# Out:
# [4, 6, 2, 1, 5, 0, 3]

# %% [markdown]
# ### Confussion Matrix

# %%
# Confusion matrix
cm = cm = confusion_matrix(y_true, y_pred, labels=classes_labels)

plt.figure(figsize= (10, 10))
plt.imshow(cm, interpolation= 'nearest', cmap= plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()

tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation= 45)
plt.yticks(tick_marks, classes)


thresh = cm.max() / 2.
for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
    plt.text(j, i, cm[i, j], horizontalalignment= 'center', color= 'white' if cm[i, j] > thresh else 'black')

plt.tight_layout()
plt.ylabel('True Label')
plt.xlabel('Predicted Label')

plt.show()

# %% [markdown]
# ### Save model

# %%
#Save the model
model.save('Skin Cancer.h5')

# %% [markdown]
# ### Convert model to tflite

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model) 
tflite_model = converter.convert() 

print("model converted")

# Save the model. 
with open('Skin.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 7). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: C:\Users\DARTHV~1\AppData\Local\Temp\tmpi50hjkva\assets
# INFO:tensorflow:Assets written to: C:\Users\DARTHV~1\AppData\Local\Temp\tmpi50hjkva\assets
# model converted

# %%
import numpy as np
from PIL import Image
from keras.models import load_model

# Load the Keras model
model_path = 'Skin Cancer.h5'
model = load_model(model_path)

# Function to predict cancer type for a single image
def predict_cancer_type(image_path):
    # Load and preprocess the input image
    image_size = (28, 28)  # Should match the size used during training
    img = Image.open(image_path)
    img = img.resize(image_size)
    img = np.array(img) / 255.0  # Normalize pixel values
    img = img.reshape(1, *img.shape)

    # Make predictions
    predicted_probabilities = model.predict(img)

    # Get the class with the highest probability as the predicted class
    predicted_class = np.argmax(predicted_probabilities)

    # Return the predicted cancer type (you may need to map class indices to labels)
    return predicted_class

# Example usage:ISIC_0024385.jpg
image_path = "cancer_type_4.jpg"
predicted_class = predict_cancer_type(image_path)
print("Predicted Class:", predicted_class)

'''
4: ('nv', ' melanocytic nevi'),
    6: ('mel', 'melanoma'),
    2 :('bkl', 'benign keratosis-like lesions'), 
    1:('bcc' , ' basal cell carcinoma'),
    5: ('vasc', ' pyogenic granulomas and hemorrhage'),
    0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),
    3: ('df', 'dermatofibroma')
'''
# Out:
# 1/1 [==============================] - 0s 197ms/step
# Predicted Class: 4
# "\n4: ('nv', ' melanocytic nevi'),\n    6: ('mel', 'melanoma'),\n    2 :('bkl', 'benign keratosis-like lesions'), \n    1:('bcc' , ' basal cell carcinoma'),\n    5: ('vasc', ' pyogenic granulomas and hemorrhage'),\n    0: ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),\n    3: ('df', 'dermatofibroma')\n"

# %%
import numpy as np
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler

y_train_single = np.argmax(y_train, axis=1)
y_test_single = np.argmax(y_test, axis=1)
num_samples, height, width, channels = X_train.shape
X_train_flat = X_train.reshape(num_samples, -1)
X_test_flat = X_test.reshape(X_test.shape[0], -1)

scaler = StandardScaler()   
X_train_scaled = scaler.fit_transform(X_train_flat)
X_test_scaled = scaler.transform(X_test_flat)

svm_classifier = SVC(kernel='linear', C=1.0) 
svm_classifier.fit(X_train_scaled, y_train_single)

svm_predictions = svm_classifier.predict(X_test_scaled)
svm_accuracy = accuracy_score(y_test_single, svm_predictions)
print("SVM Accuracy:", svm_accuracy)
# Out:
# SVM Accuracy: 0.9561956707005284

# %%
import pickle as pk
pk.dump(svm_classifier , open('SVM-model.pk1' , 'wb'))

# %%
import pickle
from sklearn.svm import SVC
import numpy as np
from PIL import Image

# Load the SVM model using pickle
model_path = 'C:/Users/DARTHVADER/Desktop/Skin_Cancer_Detection/SVM-model.pk1'
loaded_model = pickle.load(open(model_path, 'rb'))

# Function to predict cancer type for a single image
def predict_cancer_type(image_path):
    # Load and preprocess the input image
    image_size = (28, 28)  # Adjust image_size to match the expected dimensions
    img = Image.open(image_path)
    img = img.resize(image_size)
    img = np.array(img) / 255.0  # Normalize pixel values

    # Flatten the image into a 1D feature vector with 2352 features
    img_flat = img.reshape(1, -1)

    # Make predictions using the SVM model
    predicted_class = loaded_model.predict(img_flat)

    # Return the predicted cancer type (you may need to map class indices to labels)
    return predicted_class

# Example usage:
image_path = "cancer_type_4.jpg"
predicted_class = predict_cancer_type(image_path)
print("Predicted Class:", predicted_class)

'''
    4 ('nv', ' melanocytic nevi'),
    6 ('mel', 'melanoma'),
    2 ('bkl', 'benign keratosis-like lesions'), 
    1 ('bcc' , ' basal cell carcinoma'),
    5 ('vasc', ' pyogenic granulomas and hemorrhage'),
    0 ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),
    3 ('df', 'dermatofibroma')
'''
# Out:
# Predicted Class: [4]
# "\n    4 ('nv', ' melanocytic nevi'),\n    6 ('mel', 'melanoma'),\n    2 ('bkl', 'benign keratosis-like lesions'), \n    1 ('bcc' , ' basal cell carcinoma'),\n    5 ('vasc', ' pyogenic granulomas and hemorrhage'),\n    0 ('akiec', 'Actinic keratoses and intraepithelial carcinomae'),\n    3 ('df', 'dermatofibroma')\n"
